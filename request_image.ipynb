# %%
import os
import json
import logging
import requests
from urllib.parse import urlparse
import mimetypes

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("image_fetch.log"),  
        logging.StreamHandler()               
    ]
)

# %%
API_KEY = os.getenv('API_KEY', 'AIzaSyA43pbijmUNCtMNgSopT7VOimtgERBRXKU')
SEARCH_ENGINE_ID = os.getenv('SEARCH_ENGINE_ID', 'b6f2650fd0921483a')

# %%
MASTER_FILE = "all_fetched_urls.json"

# %%
def fetch_images_with_categories(category, num_results, state_file="page_state.txt"):
    """Fetch image URLs for a given category using pagination and save page state."""
    try:
        # Load the last page state
        page_state = load_page_state(state_file)
        start = page_state.get(category, 1)  # Default to the first page

        url = "https://www.googleapis.com/customsearch/v1"
        image_urls = []

        while len(image_urls) < num_results:
            params = {
                'key': API_KEY,
                'cx': SEARCH_ENGINE_ID,
                'q': category,
                'searchType': 'image',
                'num': min(10, num_results - len(image_urls)),  # Fetch up to 10 results at a time
                'start': start,
            }
            response = requests.get(url, params=params)
            response.raise_for_status()
            data = response.json()
            items = data.get('items', [])
            if not items:
                break
            image_urls.extend([item['link'] for item in items])
            start += len(items)  

        # Save the updated page state
        page_state[category] = start
        save_page_state(page_state, state_file)

        return image_urls[:num_results]
    except requests.exceptions.RequestException as e:
        logging.error(f"API request failed for {category}: {e}")
        return []

def load_page_state(state_file):
    """Load the page state from a file."""
    if os.path.exists(state_file):
        with open(state_file, "r") as file:
            return json.load(file)
    return {}

def save_page_state(page_state, state_file):
    """Save the page state to a file."""
    with open(state_file, "w") as file:
        json.dump(page_state, file)


def save_urls_to_file(urls, file_path):
    """Save a list of URLs to a JSON file.

    Args:
        urls (list[str]): List of URLs to save.
        file_path (str): Path to the JSON file to save the URLs to.

    Notes:
        The URLs are saved to the given file path after deduplicating them with any
        existing URLs in the file.
    """
    existing_urls = load_urls_from_file(file_path)
    all_urls = list(set(existing_urls).union(urls))
    with open(file_path, "w") as file:
        json.dump(all_urls, file)

def load_urls_from_file(file_path):
    """Load a list of URLs from a JSON file.

    Args:
        file_path (str): Path to the JSON file containing the URLs to load.

    Returns:
        list[str]: A list of URLs loaded from the JSON file, or an empty list if the file does not exist.
    """
    if os.path.exists(file_path):
        with open(file_path, "r") as file:
            return json.load(file)
    return []

def download_images_from_urls(urls, folder):
    """Download images from a list of URLs and save them to a specified folder.

    Args:
        urls (list[str]): List of image URLs to download.
        folder (str): Path to the folder where images will be saved.

    The function creates the folder if it does not exist and downloads each image
    from the provided URLs, saving them with their original file name. If the URL
    does not have a file extension, the function attempts to determine the extension
    from the response's content type. Logs an info message for successful downloads
    and an error message for failures.
    """

    os.makedirs(folder, exist_ok=True)
    for url in urls:
        try:
            response = requests.get(url, stream=True, allow_redirects=True)
            response.raise_for_status()
            parsed_url = urlparse(url)
            file_name = os.path.basename(parsed_url.path)
            if not os.path.splitext(file_name)[1]:
                content_type = response.headers.get('Content-Type', '')
                ext = mimetypes.guess_extension(content_type.split(';')[0]) if content_type else '.jpg'
                file_name += ext
            filepath = os.path.join(folder, file_name)
            with open(filepath, 'wb') as file:
                file.write(response.content)
            logging.info(f"Downloaded: {filepath}")
        except Exception as e:
            logging.error(f"Failed to download {url}: {e}")

def fetch_and_save_images(categories, num_results_per_category, base_folder="images", state_file="page_state.txt"):
    """Fetches images from Google Custom Search API, saves the URLs to a JSON file, and downloads the images to a folder.

    Args:
        categories (list[str]): List of categories to search for.
        num_results_per_category (int): Number of results to fetch per category.
        base_folder (str, optional): Base folder where images will be saved. Defaults to "images".
        state_file (str, optional): File path to save the state of the API request. Defaults to "page_state.txt".
    """
    os.makedirs(base_folder, exist_ok=True)
    for category in categories:
        category_folder = os.path.join(base_folder, category)
        os.makedirs(category_folder, exist_ok=True)
        urls_file = os.path.join(category_folder, "urls.json")
        images_folder = os.path.join(category_folder, "images")
        os.makedirs(images_folder, exist_ok=True)

        fetched_urls = fetch_images_with_categories(category, num_results_per_category, state_file)
        new_urls = [url for url in fetched_urls if url not in load_urls_from_file(urls_file)]
        if new_urls:
            save_urls_to_file(new_urls, urls_file)
            download_images_from_urls(new_urls, images_folder)
        else:
            logging.info(f"No new images found for category: {category}.")

# %%
# Search Query and Number of Results
categories = ["cats", "dogs", "birds", "horses", "wildlife", "flowers", "cars", "landscapes", "food"]
num_results_per_category = 10
file_path="retrieved_urls.json"

# %%
fetch_and_save_images(categories, num_results_per_category)
# Out:
# 2025-01-15 21:15:45,812 - INFO - Fetching 10 images for category: cats
# 2025-01-15 21:15:46,476 - INFO - Fetched 10 image URLs for query: cats
# 2025-01-15 21:15:46,478 - INFO - Saved 10 new URLs for cats to received_images\cats\retrieved_urls_day_cats.json
# 2025-01-15 21:15:46,867 - INFO - Downloaded: received_images\cats\images\two-different-breeds-of-cats-side-by-side-outdoors-in-the-garden.jpg
# 2025-01-15 21:15:47,767 - INFO - Downloaded: received_images\cats\images\NationalGeographic_2572187_square.jpg
# 2025-01-15 21:15:49,698 - INFO - Downloaded: received_images\cats\images\Orange-colored-cat-yawns-displaying-teeth.jpg
# 2025-01-15 21:15:50,023 - INFO - Downloaded: received_images\cats\images\NationalGeographic_1468962_square.jpg
# 2025-01-15 21:15:51,613 - INFO - Downloaded: received_images\cats\images\VIER%20PFOTEN_2020-10-07_00138-2890x2000-1920x1329.jpg
# 2025-01-15 21:15:52,119 - INFO - Downloaded: received_images\cats\images\NationalGeographic_2572187_3x4.jpg
# 2025-01-15 21:15:53,511 - INFO - Downloaded: received_images\cats\images\Sphynx_-_cat._img_031.jpg
# 2025-01-15 21:15:54,610 - ERROR - Failed to download https://vetmed.tamu.edu/news/wp-content/uploads/sites/9/2023/10/AdobeStock_542062433-1024x768.jpeg: 403 Client Error: Forbidden for url: https://vetmed.tamu.edu/news/wp-content/uploads/sites/9/2023/10/AdobeStock_542062433-1024x768.jpeg
# 2025-01-15 21:15:54,931 - INFO - Downloaded: received_images\cats\images\img-cat-whiskers-101-header.jpg
# 2025-01-15 21:15:56,427 - INFO - Downloaded: received_images\cats\images\cut%20cat%20serhio%2002-1813x1811-720x719.jpg
# 2025-01-15 21:15:56,430 - INFO - Fetching 10 images for category: dogs
# 2025-01-15 21:15:57,446 - INFO - Fetched 10 image URLs for query: dogs
# 2025-01-15 21:15:57,448 - INFO - Saved 10 new URLs for dogs to received_images\dogs\retrieved_urls_day_dogs.json
# 2025-01-15 21:15:58,715 - INFO - Downloaded: received_images\dogs\images\GettyImages-1445770180.jpg
# 2025-01-15 21:15:59,444 - INFO - Downloaded: received_images\dogs\images\domestic-dog_thumb_3x2.jpg
# 2025-01-15 21:15:59,702 - INFO - Downloaded: received_images\dogs\images\trains-both-shelter-dogs-and-purpose-bred-dogs-as-service-dogs.png
# 2025-01-15 21:16:00,052 - INFO - Downloaded: received_images\dogs\images\GettyImages-598175960-cute-dog-headshot.jpg
# 2025-01-15 21:16:02,912 - INFO - Downloaded: received_images\dogs\images\69fd7126-778b-4a3e-ae57-b842388c83fe.jpg
# 2025-01-15 21:16:05,847 - INFO - Downloaded: received_images\dogs\images\Blog-Why-How-1024x683.png
# 2025-01-15 21:16:06,473 - INFO - Downloaded: received_images\dogs\images\Q3-24-HP-promo.jpg
# 2025-01-15 21:16:06,912 - INFO - Downloaded: received_images\dogs\images\AR-JF-35149-Homemade-Corn-Dogs-4x3-86d5f822adc144a5bc6e8d3aa897e476.jpg
# 2025-01-15 21:16:08,458 - INFO - Downloaded: received_images\dogs\images\20240928130759-1024x1024.jpg
# 2025-01-15 21:16:08,852 - INFO - Downloaded: received_images\dogs\images\dog-breed-height-comparison.jpg
# 2025-01-15 21:16:08,855 - INFO - Fetching 10 images for category: birds
# 2025-01-15 21:16:09,441 - INFO - Fetched 10 image URLs for query: birds
# 2025-01-15 21:16:09,443 - INFO - Saved 10 new URLs for birds to received_images\birds\retrieved_urls_day_birds.json
# 2025-01-15 21:16:09,860 - INFO - Downloaded: received_images\birds\images\300px-Bird_Diversity_2013.png
# 2025-01-15 21:16:10,398 - INFO - Downloaded: received_images\birds\images\AmericanGoldfinch_MattWilliams_4000x2200.jpg
# 2025-01-15 21:16:10,706 - INFO - Downloaded: received_images\birds\images\Zebra-finch-Taeniopygia-guttata-bird.jpg
# 2025-01-15 21:16:11,219 - INFO - Downloaded: received_images\birds\images\WC202209_LAST_006_430968_reduced.jpg
# 2025-01-15 21:16:12,552 - INFO - Downloaded: received_images\birds\images\7A715AD8-449D-4B5A-ABA2C5D92D9B5A21_source.png
# 2025-01-15 21:16:12,834 - INFO - Downloaded: received_images\birds\images\Taiwan-Blue-Magpie-web-768x432.jpg
# 2025-01-15 21:16:15,678 - INFO - Downloaded: received_images\birds\images\cardinal-bird-branch-1024x676.jpg
# 2025-01-15 21:16:16,213 - INFO - Downloaded: received_images\birds\images\334289821-Baltimore_Oriole-Matthew_Plante.jpg
# 2025-01-15 21:16:16,756 - INFO - Downloaded: received_images\birds\images\WC202209_LAST_006_430968_reduced.jpg
# 2025-01-15 21:16:18,707 - INFO - Downloaded: received_images\birds\images\Osprey.jpg
# 2025-01-15 21:16:18,709 - INFO - Fetching 10 images for category: horses
# 2025-01-15 21:16:19,316 - INFO - Fetched 10 image URLs for query: horses
# 2025-01-15 21:16:19,319 - INFO - Saved 10 new URLs for horses to received_images\horses\retrieved_urls_day_horses.json
# 2025-01-15 21:16:19,613 - INFO - Downloaded: received_images\horses\images\Nokota_Horses_cropped.jpg
# 2025-01-15 21:16:21,846 - INFO - Downloaded: received_images\horses\images\power-what-can-horses-teach-us-2-scaled-1.jpg
# 2025-01-15 21:16:23,955 - INFO - Downloaded: received_images\horses\images\horsesrunningbeach_2.jpg
# 2025-01-15 21:16:24,754 - INFO - Downloaded: received_images\horses\images\Horses-Digestive-System.png
# 2025-01-15 21:16:25,326 - INFO - Downloaded: received_images\horses\images\falling-star-great_orig.jpg
# 2025-01-15 21:16:25,690 - INFO - Downloaded: received_images\horses\images\H8R79odorHBXmDLQw9kzUk-1200-80.jpg
# 2025-01-15 21:16:26,017 - INFO - Downloaded: received_images\horses\images\types-horse-markings.jpg
# 2025-01-15 21:16:30,820 - INFO - Downloaded: received_images\horses\images\RS17966_Lika-Plains-Horses-2-ed.jpg
# 2025-01-15 21:16:33,406 - INFO - Downloaded: received_images\horses\images\horsesrunningbeach_2.jpg
# 2025-01-15 21:16:35,797 - INFO - Downloaded: received_images\horses\images\UAR_Website_cover_images_landing_pages_7-min.jpg
# 2025-01-15 21:16:35,802 - INFO - Fetching 10 images for category: wildlife
# 2025-01-15 21:16:36,447 - INFO - Fetched 10 image URLs for query: wildlife
# 2025-01-15 21:16:36,450 - INFO - Saved 10 new URLs for wildlife to received_images\wildlife\retrieved_urls_day_wildlife.json
# 2025-01-15 21:16:36,674 - ERROR - Failed to download https://upload.wikimedia.org/wikipedia/commons/7/7d/Wildlife_at_Maasai_Mara_%28Lion%29.jpg: 403 Client Error: Forbidden. Please comply with the User-Agent policy: https://meta.wikimedia.org/wiki/User-Agent_policy for url: https://upload.wikimedia.org/wikipedia/commons/7/7d/Wildlife_at_Maasai_Mara_%28Lion%29.jpg
# 2025-01-15 21:16:37,287 - ERROR - Failed to download https://unity.edu/wp-content/uploads/2020/04/a-veterinarian-is-caring-for-a-newborn-baby-deer-i-2023-06-20-10-00-12-utc-scaled.jpg: 403 Client Error: Forbidden for url: https://unity.edu/wp-content/uploads/2020/04/a-veterinarian-is-caring-for-a-newborn-baby-deer-i-2023-06-20-10-00-12-utc-scaled.jpg
# 2025-01-15 21:16:38,162 - INFO - Downloaded: received_images\wildlife\images\SavingWildlife1.jpg
# 2025-01-15 21:16:38,683 - INFO - Downloaded: received_images\wildlife\images\31291306-bosque-del-apache-national-wildlife-refuge-wildlife-us-fish-wildlife-kristina-lauer-2018.jpg
# 2025-01-15 21:16:39,792 - INFO - Downloaded: received_images\wildlife\images\6%20World%20Wildlife%20Day%202024%20Official%20Poster%20Contest-English-Twitter.png
# 2025-01-15 21:16:40,399 - ERROR - Failed to download https://www.nwf.org/-/media/NEW-WEBSITE/Design/nwf_social_share_default_v1.jpg: HTTPSConnectionPool(host='www.nwf.org', port=443): Max retries exceeded with url: /-/media/NEW-WEBSITE/Design/nwf_social_share_default_v1.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# 2025-01-15 21:16:42,456 - INFO - Downloaded: received_images\wildlife\images\baby-giraffe-amari-1024x683.jpg
# 2025-01-15 21:16:43,137 - INFO - Downloaded: received_images\wildlife\images\1200px-Wildlife_at_Maasai_Mara_%28Lion%29.jpg
# 2025-01-15 21:16:45,622 - INFO - Downloaded: received_images\wildlife\images\wildlife-park-bear.jpg
# 2025-01-15 21:16:46,318 - INFO - Downloaded: received_images\wildlife\images\gray-wolf-pup-mn-1372772954.jpg.jpg
# 2025-01-15 21:16:46,321 - INFO - Fetching 10 images for category: flowers
# 2025-01-15 21:16:47,106 - INFO - Fetched 10 image URLs for query: flowers
# 2025-01-15 21:16:47,108 - INFO - Saved 10 new URLs for flowers to received_images\flowers\retrieved_urls_day_flowers.json
# 2025-01-15 21:16:47,381 - INFO - Downloaded: received_images\flowers\images\330px-Flower_poster_2.jpg
# 2025-01-15 21:16:48,263 - INFO - Downloaded: received_images\flowers\images\JI230816Cosmos220-6d9254f-edited-scaled.jpg
# 2025-01-15 21:16:49,577 - INFO - Downloaded: received_images\flowers\images\FYF-116.jpg
# 2025-01-15 21:16:49,931 - ERROR - Failed to download https://www.stadiumflowers.com/images/itemVariation/v4_2024-07-FarmFresh-Deluxe-24070770804.JPEG: 403 Client Error: Forbidden for url: https://www.stadiumflowers.com/images/itemVariation/v4_2024-07-FarmFresh-Deluxe-24070770804.JPEG
# 2025-01-15 21:16:50,180 - ERROR - Failed to download https://www.allensflowers.com/images/itemVariation/v4_boldandbeautiful2024-231219115007.jpg: 403 Client Error: Forbidden for url: https://www.allensflowers.com/images/itemVariation/v4_boldandbeautiful2024-231219115007.jpg
# 2025-01-15 21:16:50,483 - ERROR - Failed to download https://www.rosehillflowers.com/images/itemVariation/v4_ultimateflowers-240404114301.jpg: 403 Client Error: Forbidden for url: https://www.rosehillflowers.com/images/itemVariation/v4_ultimateflowers-240404114301.jpg
# 2025-01-15 21:16:51,943 - INFO - Downloaded: received_images\flowers\images\TEV68-3A.jpg
# 2025-01-15 21:16:52,440 - INFO - Downloaded: received_images\flowers\images\merchandising-flowers-page-167753.jpg
# 2025-01-15 21:17:18,243 - INFO - Downloaded: received_images\flowers\images\rosa_red_cut_flower_1.jpg
# 2025-01-15 21:17:18,488 - INFO - Downloaded: received_images\flowers\images\20230217025255_file_63eeec0786a7a_63eeef57dc8de.jpg
# 2025-01-15 21:17:18,491 - INFO - Fetching 10 images for category: cars
# 2025-01-15 21:17:19,214 - INFO - Fetched 10 image URLs for query: cars
# 2025-01-15 21:17:19,216 - INFO - Saved 10 new URLs for cars to received_images\cars\retrieved_urls_day_cars.json
# 2025-01-15 21:17:19,594 - INFO - Downloaded: received_images\cars\images\2025-10best-cars-winners-674634317da76.jpg
# 2025-01-15 21:17:20,035 - INFO - Downloaded: received_images\cars\images\homepage-hero-m.jpg
# 2025-01-15 21:17:20,242 - INFO - Downloaded: received_images\cars\images\2025-ford-mustang-60th-anniversary-exterior-66227932bb88e.jpg
# 2025-01-15 21:17:20,619 - INFO - Downloaded: received_images\cars\images\MV5BMTg5NzY0MzA2MV5BMl5BanBnXkFtZTYwNDc3NTc2._V1_FMjpg_UX1000_.jpg
# 2025-01-15 21:17:21,056 - INFO - Downloaded: received_images\cars\images\18015-MC20BluInfinito-scaled-e1707920217641.jpg
# 2025-01-15 21:17:21,308 - INFO - Downloaded: received_images\cars\images\220px-Cars_2006.jpg
# 2025-01-15 21:17:23,150 - INFO - Downloaded: received_images\cars\images\h_cars3_mobile_19643_3bab859a.jpeg
# 2025-01-15 21:17:23,458 - INFO - Downloaded: received_images\cars\images\most-powerful-cars-in-the-world.webp
# 2025-01-15 21:17:23,728 - INFO - Downloaded: received_images\cars\images\Cars_2006.jpg
# 2025-01-15 21:17:24,479 - INFO - Downloaded: received_images\cars\images\00722-Cars-_Blackstone__Rounded.png
# 2025-01-15 21:17:24,481 - INFO - Fetching 10 images for category: landscapes
# 2025-01-15 21:17:25,076 - INFO - Fetched 10 image URLs for query: landscapes
# 2025-01-15 21:17:25,080 - INFO - Saved 10 new URLs for landscapes to received_images\landscapes\retrieved_urls_day_landscapes.json
# 2025-01-15 21:17:25,555 - INFO - Downloaded: received_images\landscapes\images\2022-08-08_Maara-21333-Edit-1.jpg
# 2025-01-15 21:17:25,856 - INFO - Downloaded: received_images\landscapes\images\659e6c1875a6ef6d59572be3_types%20of%20landscapes.webp
# 2025-01-15 21:17:26,799 - INFO - Downloaded: received_images\landscapes\images\RS22525__scr-e1695214632666-1024x688.jpg
# 2025-01-15 21:17:27,062 - INFO - Downloaded: received_images\landscapes\images\65ea95887efa5c72ece1abb0_most%20beautiful%20landscapes%20in%20the%20world.webp
# 2025-01-15 21:17:28,664 - INFO - Downloaded: received_images\landscapes\images\pexels-photo-346529.jpeg
# 2025-01-15 21:17:29,297 - INFO - Downloaded: received_images\landscapes\images\cover-photo-mountain-underwater_8193400c-d58b-4f41-b277-e9d1e6238926.jpg
# 2025-01-15 21:17:29,600 - INFO - Downloaded: received_images\landscapes\images\patagonia-torresdelpaine-jvnphoto-thumb.jpg
# 2025-01-15 21:17:30,119 - INFO - Downloaded: received_images\landscapes\images\mM87l2ZsQRSawMLLRlFF_FallLandscape7-.jpg
# 2025-01-15 21:17:31,506 - INFO - Downloaded: received_images\landscapes\images\Primary-Perspective-hires.jpg
# 2025-01-15 21:17:33,819 - INFO - Downloaded: received_images\landscapes\images\swiss-mountains.jpg
# 2025-01-15 21:17:33,821 - INFO - Fetching 10 images for category: food
# 2025-01-15 21:17:34,603 - INFO - Fetched 10 image URLs for query: food
# 2025-01-15 21:17:34,605 - INFO - Saved 10 new URLs for food to received_images\food\retrieved_urls_day_food.json
# 2025-01-15 21:17:34,918 - INFO - Downloaded: received_images\food\images\640px-Good_Food_Display_-_NCI_Visuals_Online.jpg
# 2025-01-15 21:17:36,683 - INFO - Downloaded: received_images\food\images\neat_emmapharaoh_19march24_12.jpg
# 2025-01-15 21:17:38,496 - INFO - Downloaded: received_images\food\images\foodgroupslp_804x482.jpg
# 2025-01-15 21:17:39,331 - INFO - Downloaded: received_images\food\images\aug-2023-cover-illustration-different-types-foods-five-food-groups-vegetables-fruits-dairy-products-oils-proteins.jpg
# 2025-01-15 21:17:40,428 - INFO - Downloaded: received_images\food\images\MIT_Food-Diabetes-01_0.jpg
# 2025-01-15 21:17:40,835 - INFO - Downloaded: received_images\food\images\Variety-fruits-vegetables.jpg
# 2025-01-15 21:17:43,195 - INFO - Downloaded: received_images\food\images\Good_Food_Display_-_NCI_Visuals_Online.jpg
# 2025-01-15 21:17:43,627 - INFO - Downloaded: received_images\food\images\burger-with-melted-cheese.jpg
# 2025-01-15 21:17:44,246 - INFO - Downloaded: received_images\food\images\9dfaeda73538877faf9c927ec8c8d6863c2c2111-4800x3200.jpg
# 2025-01-15 21:17:44,622 - INFO - Downloaded: received_images\food\images\800px-Good_Food_Display_-_NCI_Visuals_Online.jpg
